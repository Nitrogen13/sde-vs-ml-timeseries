# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np

# %%
df = pd.read_csv("percent_results2.csv")
df
# Out:
#       Unnamed: 0  kappa   theta_a  theta_b  sigma  error_kappa  error_theta_a  \
# 0              0   0.01  0.000001    0.005    0.5     92.84718     3073.91911
# 1              1   0.01  0.000001    0.010    0.5   1140.59671       99.99996
# 2              2   0.01  0.000001    0.020    0.5    753.54204      313.17581
# 3              3   0.01  0.000001    0.050    0.5    298.61348       97.12932
# 4              4   0.01  0.000001    0.100    0.5    757.07181       36.30317
# ...          ...    ...       ...      ...    ...          ...            ...
# 1051        1051  20.00  0.100000    0.010    2.0     81.94471       99.98115
# 1052        1052  20.00  0.100000    0.020    2.0     81.60929       99.98126
# 1053        1053  20.00  0.100000    0.050    2.0     82.09940       99.98133
# 1054        1054  20.00  0.100000    0.100    2.0     82.78283       99.98127
# 1055        1055  20.00  0.100000    0.500    2.0     82.07193       99.98126
#
#       error_theta_b  error_sigma
# ...

# %%
df = df[df["sigma"] == 0.5][["kappa", "theta_a", "theta_b", "error_kappa", "error_theta_a", "error_theta_b"]]
df
# Out:
#       kappa   theta_a  theta_b  error_kappa  error_theta_a  error_theta_b
# 0      0.01  0.000001    0.005     92.84718     3073.91911      100.00000
# 1      0.01  0.000001    0.010   1140.59671       99.99996    42342.45854
# 2      0.01  0.000001    0.020    753.54204      313.17581     7385.06749
# 3      0.01  0.000001    0.050    298.61348       97.12932     3599.43431
# 4      0.01  0.000001    0.100    757.07181       36.30317     1237.65892
# ...     ...       ...      ...          ...            ...            ...
# 1003  20.00  0.100000    0.010     99.69531       99.98566    48421.37516
# 1004  20.00  0.100000    0.020     99.69560       99.98579    24218.54985
# 1005  20.00  0.100000    0.050     99.69539       99.98558     9684.88415
# 1006  20.00  0.100000    0.100     99.68930       99.98569     4847.00268
# 1007  20.00  0.100000    0.500     99.67155       99.98609      969.63538
#
# [528 rows x 6 columns]

# %%
param_name_1 = "kappa"
param_name_2 = "theta_b"
target = "theta_a"

unique_values_1 = df[param_name_1].unique()
unique_values_2 = df[param_name_2].unique()

for param_1 in unique_values_1:
    for param_2 in unique_values_2:
        dataframe = df[df[param_name_1] == param_1][df[param_name_2] == param_2]
        x = dataframe[target]
        y = dataframe["error_" + target] 
        plt.figure() 
        plt.title(f"{param_name_1} = {param_1}, {param_name_2} = {param_2}")
        plt.plot(x,y)
        plt.show()
# Out:
# /home/ilgizar/thesis/Thesis/venv/lib/python3.7/site-packages/ipykernel_launcher.py:10: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   # Remove the CWD from sys.path while we load stuff.
